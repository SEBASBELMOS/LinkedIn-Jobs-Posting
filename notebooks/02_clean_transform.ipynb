# %% [markdown]
# ## **PROJECT - NOTEBOOK #2: Data Cleansing, transformation and Exploratory Data Analysis (EDA)**
#
# ---

# %% [markdown]
# ### **Setting Environment**

# %%
import os 
print(os.getcwd())

try:
    os.chdir("../../project_etl")

except FileNotFoundError:
    print("""
        FileNotFoundError - The directory may not exist or you might not be in the specified path.
        If this has already worked, do not run this block again, as the current directory is already set to workshop-001.
        """)
    
print(os.getcwd())
# Out:
# d:\U\FIFTH SEMESTER\ETL\project_etl
#
#         FileNotFoundError - The directory may not exist or you might not be in the specified path.
#         If this has already worked, do not run this block again, as the current directory is already set to workshop-001.
#
# d:\U\FIFTH SEMESTER\ETL\project_etl

# %% [markdown]
# ### **Load Data**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

from functions.db_connection.connection import creating_engine

# %%
engine = creating_engine()

# %% [markdown]
# ### **Load Database**

# %%
#df = pd.read_sql_query("SELECT * FROM jobs LIMIT 1000", engine)    #Select a batch
df = pd.read_sql_table("jobs", engine) #Select all the data
df
# Out:
#             job_id              company_name  \
# 0       3890893642             SNI Companies
# 1       3890893652       AllSTEM Connections
# 2       3890893741                 DNSFilter
# 3       3890893839  Avesta Computer Services
# 4       3890893845                 WhatBytes
# ...            ...                       ...
# 123844  3890893607            Premise Health
# 123845  3890893615     V&V Supremo Foods Inc
# 123846  3890893623       Bluehawk Consulting
# 123847  3890893631           Procorp Systems
# 123848  3890894330           LanceSoft, Inc.
#
#                                                   title  \
# 0                                     Policy Specialist
# 1                          Lead Python Backend Engineer
# 2                   Senior Enterprise Account Executive
# 3                      Artificial Intelligence Engineer
# 4                                       Startup Advisor
# ...                                                 ...
# 123844                                Field Requisition
# 123845                                   Safety Manager
# 123846                           Database Administrator
# 123847  JAVA FSD+ Python + AWS - Tampa, FL(Day1 onsite)
# 123848                            Laboratory Technician
#
#                                               description  max_salary  \
# 0       SNI Companies has partnered with an amazing or...         NaN
# 1       Lead Python Backend Engineer. 170K-180K base. ...         NaN
# 2       At DNSFilter we are making workplaces more sec...         NaN
# 3       Client - “Our customer is a Top 20 Global inve...         NaN
# 4       About WhatBytes\nWhatBytes is an innovative pr...         NaN
# ...                                                   ...         ...
# 123844  Healthcare Without Rival\nPremise offers a wid...         NaN
# 123845  Position Title:  Safety Manager  Department: O...         NaN
# 123846  DBARetire all of the Windows 2012 servers with...    132000.0
# 123847  JAVA FSD+ Python + AWSTampa, FL(Day1 onsite) L...         NaN
# 123848  Title: Lab Assistant (Cheese Culture Tech)Loca...         NaN
#
#        pay_period                location  company_id  views  med_salary  ...  \
# 0          HOURLY              Austin, TX    971273.0    3.0       19.25  ...
# 1            None           United States  35475885.0    6.0         NaN  ...
# 2            None           United States  10288375.0    6.0         NaN  ...
# 3            None       Newport Beach, CA     34616.0    5.0         NaN  ...
# 4            None  San Francisco Bay Area  99400379.0    1.0         NaN  ...
# ...           ...                     ...         ...    ...         ...  ...
# 123844       None               Pella, IA   3281403.0    2.0         NaN  ...
# 123845       None             Chicago, IL   6017632.0    5.0         NaN  ...
# 123846     YEARLY             Seattle, WA   3056209.0    6.0         NaN  ...
# 123847       None               Tampa, FL  74360153.0    9.0         NaN  ...
# 123848       None        Morton Grove, IL     16388.0    4.0         NaN  ...
#
#         skills_desc   listed_time              posting_domain  sponsored  \
# 0              None  1.712857e+12                        None          0
# 1              None  1.712857e+12                        None          0
# 2              None  1.712857e+12                        None          0
# 3              None  1.712857e+12                        None          0
# 4              None  1.712857e+12                        None          0
# ...             ...           ...                         ...        ...
# 123844         None  1.712856e+12  premisehealth2.avature.net          0
# 123845         None  1.712857e+12                        None          0
# 123846         None  1.712857e+12                        None          0
# 123847         None  1.712857e+12                        None          0
# 123848         None  1.712856e+12                        None          0
#
#         work_type currency compensation_type normalized_salary  zip_code  \
# 0       FULL_TIME      USD       BASE_SALARY           40040.0   78701.0
# 1       FULL_TIME     None              None               NaN       NaN
# 2       FULL_TIME     None              None               NaN       NaN
# 3       FULL_TIME     None              None               NaN   92660.0
# 4       FULL_TIME     None              None               NaN       NaN
# ...           ...      ...               ...               ...       ...
# 123844  PART_TIME     None              None               NaN   50219.0
# 123845  FULL_TIME     None              None               NaN   60601.0
# 123846   CONTRACT      USD       BASE_SALARY          126000.0   98101.0
# 123847   CONTRACT     None              None               NaN   33602.0
# 123848   CONTRACT     None              None               NaN   60053.0
#
#            fips
# 0       48453.0
# 1           NaN
# 2           NaN
# 3        6059.0
# 4           NaN
# ...         ...
# 123844  19125.0
# 123845  17031.0
# 123846  53033.0
# 123847  12057.0
# 123848  17031.0
#
# [123849 rows x 31 columns]

# %% [markdown]
# ### **Understanding the dataset**

# %% [markdown]
# #### **Data column details**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123849 entries, 0 to 123848
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   job_id                      123849 non-null  int64
#  1   company_name                122130 non-null  object
#  2   title                       123849 non-null  object
#  3   description                 123842 non-null  object
#  4   max_salary                  29793 non-null   float64
#  5   pay_period                  36073 non-null   object
#  6   location                    123849 non-null  object
#  7   company_id                  122132 non-null  float64
#  8   views                       122160 non-null  float64
#  9   med_salary                  6280 non-null    float64
#  10  min_salary                  29793 non-null   float64
#  11  formatted_work_type         123849 non-null  object
#  12  applies                     23320 non-null   float64
#  13  original_listed_time        123849 non-null  float64
#  14  remote_allowed              15246 non-null   float64
#  15  job_posting_url             123849 non-null  object
#  16  application_url             87184 non-null   object
#  17  application_type            123849 non-null  object
#  18  expiry                      123849 non-null  float64
#  19  closed_time                 1073 non-null    float64
#  20  formatted_experience_level  94440 non-null   object
#  21  skills_desc                 2439 non-null    object
#  22  listed_time                 123849 non-null  float64
#  23  posting_domain              83881 non-null   object
#  24  sponsored                   123849 non-null  int64
#  25  work_type                   123849 non-null  object
#  26  currency                    36073 non-null   object
#  27  compensation_type           36073 non-null   object
#  28  normalized_salary           36073 non-null   float64
#  29  zip_code                    102977 non-null  float64
#  30  fips                        96434 non-null   float64
# dtypes: float64(14), int64(2), object(15)
# memory usage: 29.3+ MB

# %% [markdown]
# #### **Examining the dataset for duplicate rows.**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### **Examining the dataset for null values.**

# %%
df.isnull().sum()
# Out:
# job_id                             0
# company_name                    1719
# title                              0
# description                        7
# max_salary                     94056
# pay_period                     87776
# location                           0
# company_id                      1717
# views                           1689
# med_salary                    117569
# min_salary                     94056
# formatted_work_type                0
# applies                       100529
# original_listed_time               0
# remote_allowed                108603
# job_posting_url                    0
# application_url                36665
# application_type                   0
# expiry                             0
# closed_time                   122776
# formatted_experience_level     29409
# skills_desc                   121410
# listed_time                        0
# posting_domain                 39968
# sponsored                          0
# work_type                          0
# currency                       87776
# compensation_type              87776
# normalized_salary              87776
# zip_code                       20872
# fips                           27415
# dtype: int64

# %% [markdown]
# #### **Counting unique values in each column**

# %%
df.nunique()
# Out:
# job_id                        123849
# company_name                   24428
# title                          72521
# description                   107827
# max_salary                      5321
# pay_period                         5
# location                        8526
# company_id                     24474
# views                            684
# med_salary                      1417
# min_salary                      4612
# formatted_work_type                7
# applies                          274
# original_listed_time           65036
# remote_allowed                     1
# job_posting_url               123849
# application_url                84800
# application_type                   4
# expiry                         54851
# closed_time                      698
# formatted_experience_level         6
# skills_desc                     2212
# listed_time                    53231
# posting_domain                  4443
# sponsored                          1
# work_type                          7
# currency                           6
# compensation_type                  1
# normalized_salary               7259
# zip_code                        6989
# fips                            2270
# dtype: int64
